# %%
# Visualize from log

# auto reload
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

from cfpilot.visualization import FlightDataPlotter


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
# Load the log data
log_path = "../logs/flight_log_20250925_163416.csv"
log_data = pd.read_csv(log_path)

plotter = FlightDataPlotter(log_path)
    
if not plotter.load_data():
    raise ValueError('Failed to load log data')
    
save_dir = Path("../logs/")


save_path = save_dir / 'flight_trajectory.png' if save_dir else None
plotter.plot_flight_trajectory(save_path)

save_path = save_dir / 'landing_detection.png' if save_dir else None
# plotter.plot_landing_pad_detection(save_path)

save_path = save_dir / 'flight_report.json' if save_dir else None
# plotter.generate_report(save_path)
# Out:
# ✅ Loaded 136 data points from ../logs/flight_log_20250925_163416.csv
# 📊 Columns: ['stateEstimate.x', 'stateEstimate.y', 'stateEstimate.z', 'pm.vbat', 'range.front', 'range.back', 'range.up', 'range.left', 'range.right', 'range.zrange', 'stabilizer.roll', 'stabilizer.pitch', 'stabilizer.yaw']
# 📊 Flight trajectory saved to ../logs/flight_trajectory.png

# %%
# Out:
#      stateEstimate.x  stateEstimate.y  stateEstimate.z   pm.vbat  range.front  \
# 0           0.009492         0.032731         0.433298  3.721408        32766
# 1           0.012984         0.032086         0.458946  3.742522        32766
# 2           0.021204         0.030837         0.482799  3.747801        32766
# 3           0.032195         0.029334         0.503264  3.753079        32766
# 4           0.034067         0.026678         0.518669  3.747801        32766
# ..               ...              ...              ...       ...          ...
# 131         1.217734        -0.177095         0.504532  3.679179        32766
# 132         1.237419        -0.181267         0.504544  3.684458        32766
# 133         1.259168        -0.184608         0.504473  3.679179        32766
# 134         1.285456        -0.183771         0.502788  3.679179        32766
# 135         1.305067        -0.182288         0.502545  3.679179        32766
#
#      range.back  range.up  range.left  range.right  range.zrange  \
# 0          1374     32766         805         1987           431
# 1          1377     32766         825        32766           457
# 2          1385     32766         857        32766           481
# 3          1392     32766         924        32766           501
# 4          1399     32766        1172         1870           517
# ..          ...       ...         ...          ...           ...
# 131        2316     32766        1465        32766           504
# 132        2339     32766        1456        32766           503
# 133        2356     32766        1467        32766           505
# 134        2382     32766        1472        32766           501
# 135        2395     32766        1474         1490           503
#
#      stabilizer.roll  stabilizer.pitch  stabilizer.yaw  time_elapsed
# 0           0.405285         -0.057184        1.894364           0.0
# 1           0.197240          0.310955        1.933870           0.1
# 2           0.028375          0.482743        1.894235           0.2
# 3          -0.110314          0.770407        1.606775           0.3
# 4          -0.139855          0.795261        1.258989           0.4
# ..               ...               ...             ...           ...
# 131        -0.461104         -0.011452        3.709471          13.1
# 132        -0.595349         -0.015299        4.857168          13.2
# 133        -0.657767          0.005298        5.891001          13.3
# 134        -0.628557          0.011584        6.678684          13.4
# 135        -0.547771          0.208539        7.376241          13.5
#
# [136 rows x 14 columns]
